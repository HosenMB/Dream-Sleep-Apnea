# %%
from google.colab import drive
drive.mount('/content/gdrive')
# Out:
# Mounted at /content/gdrive

# %%
# !mkdir -p ~/.kaggle
# !cp "/content/gdrive/My Drive/kaggleJson/kaggle.json" ~/.kaggle/
# !chmod 600 ~/.kaggle/kaggle.json

# %%
# !kaggle datasets download -d masud1901/binary-classification-data-for-apnea-detection
# !unzip binary-classification-data-for-apnea-detection.zip
# Out:
# Streaming output truncated to the last 5000 lines.
#   inflating: Binary_Classification_Apnea/non_apnea/31576.png
#   inflating: Binary_Classification_Apnea/non_apnea/31577.png
#   inflating: Binary_Classification_Apnea/non_apnea/31578.png
#   inflating: Binary_Classification_Apnea/non_apnea/31579.png
#   inflating: Binary_Classification_Apnea/non_apnea/31580.png
#   inflating: Binary_Classification_Apnea/non_apnea/31581.png
#   inflating: Binary_Classification_Apnea/non_apnea/31582.png
#   inflating: Binary_Classification_Apnea/non_apnea/31583.png
#   inflating: Binary_Classification_Apnea/non_apnea/31584.png
#   inflating: Binary_Classification_Apnea/non_apnea/31585.png
#   inflating: Binary_Classification_Apnea/non_apnea/31586.png
#   inflating: Binary_Classification_Apnea/non_apnea/31587.png
#   inflating: Binary_Classification_Apnea/non_apnea/31588.png
#   inflating: Binary_Classification_Apnea/non_apnea/31589.png
#   inflating: Binary_Classification_Apnea/non_apnea/31590.png
#   inflating: Binary_Classification_Apnea/non_apnea/31591.png
#   inflating: Binary_Classification_Apnea/non_apnea/31592.png
#   inflating: Binary_Classification_Apnea/non_apnea/31593.png
#   inflating: Binary_Classification_Apnea/non_apnea/31594.png
#   inflating: Binary_Classification_Apnea/non_apnea/31595.png
#   inflating: Binary_Classification_Apnea/non_apnea/31596.png
#   inflating: Binary_Classification_Apnea/non_apnea/31597.png
#   inflating: Binary_Classification_Apnea/non_apnea/31598.png
#   inflating: Binary_Classification_Apnea/non_apnea/31599.png
#   inflating: Binary_Classification_Apnea/non_apnea/31600.png
#   inflating: Binary_Classification_Apnea/non_apnea/31601.png
#   inflating: Binary_Classification_Apnea/non_apnea/31602.png
#   inflating: Binary_Classification_Apnea/non_apnea/31603.png
#   inflating: Binary_Classification_Apnea/non_apnea/31604.png
#   inflating: Binary_Classification_Apnea/non_apnea/31605.png
#   inflating: Binary_Classification_Apnea/non_apnea/31606.png
#   inflating: Binary_Classification_Apnea/non_apnea/31607.png
#   inflating: Binary_Classification_Apnea/non_apnea/31608.png
#   inflating: Binary_Classification_Apnea/non_apnea/31609.png
#   inflating: Binary_Classification_Apnea/non_apnea/31610.png
#   inflating: Binary_Classification_Apnea/non_apnea/31611.png
#   inflating: Binary_Classification_Apnea/non_apnea/31612.png
#   inflating: Binary_Classification_Apnea/non_apnea/31613.png
#   inflating: Binary_Classification_Apnea/non_apnea/31614.png
#   inflating: Binary_Classification_Apnea/non_apnea/31615.png
#   inflating: Binary_Classification_Apnea/non_apnea/31616.png
#   inflating: Binary_Classification_Apnea/non_apnea/31617.png
#   inflating: Binary_Classification_Apnea/non_apnea/31618.png
#   inflating: Binary_Classification_Apnea/non_apnea/31619.png
#   inflating: Binary_Classification_Apnea/non_apnea/31620.png
#   inflating: Binary_Classification_Apnea/non_apnea/31621.png
#   inflating: Binary_Classification_Apnea/non_apnea/31622.png
#   inflating: Binary_Classification_Apnea/non_apnea/31623.png
#   inflating: Binary_Classification_Apnea/non_apnea/31624.png
#   inflating: Binary_Classification_Apnea/non_apnea/31625.png
#   inflating: Binary_Classification_Apnea/non_apnea/31626.png
#   inflating: Binary_Classification_Apnea/non_apnea/31627.png
#   inflating: Binary_Classification_Apnea/non_apnea/31628.png
#   inflating: Binary_Classification_Apnea/non_apnea/31629.png
#   inflating: Binary_Classification_Apnea/non_apnea/31630.png
#   inflating: Binary_Classification_Apnea/non_apnea/31631.png
#   inflating: Binary_Classification_Apnea/non_apnea/31632.png
#   inflating: Binary_Classification_Apnea/non_apnea/31633.png
#   inflating: Binary_Classification_Apnea/non_apnea/31634.png
#   inflating: Binary_Classification_Apnea/non_apnea/31635.png
#   inflating: Binary_Classification_Apnea/non_apnea/31636.png
#   inflating: Binary_Classification_Apnea/non_apnea/31637.png
#   inflating: Binary_Classification_Apnea/non_apnea/31638.png
#   inflating: Binary_Classification_Apnea/non_apnea/31639.png
#   inflating: Binary_Classification_Apnea/non_apnea/31640.png
#   inflating: Binary_Classification_Apnea/non_apnea/31641.png
#   inflating: Binary_Classification_Apnea/non_apnea/31642.png
#   inflating: Binary_Classification_Apnea/non_apnea/31643.png
#   inflating: Binary_Classification_Apnea/non_apnea/31644.png
#   inflating: Binary_Classification_Apnea/non_apnea/31645.png
#   inflating: Binary_Classification_Apnea/non_apnea/31646.png
#   inflating: Binary_Classification_Apnea/non_apnea/31647.png
#   inflating: Binary_Classification_Apnea/non_apnea/31648.png
#   inflating: Binary_Classification_Apnea/non_apnea/31649.png
#   inflating: Binary_Classification_Apnea/non_apnea/31650.png
#   inflating: Binary_Classification_Apnea/non_apnea/31651.png
#   inflating: Binary_Classification_Apnea/non_apnea/31652.png
#   inflating: Binary_Classification_Apnea/non_apnea/31653.png
#   inflating: Binary_Classification_Apnea/non_apnea/31654.png
#   inflating: Binary_Classification_Apnea/non_apnea/31655.png
#   inflating: Binary_Classification_Apnea/non_apnea/31656.png
#   inflating: Binary_Classification_Apnea/non_apnea/31657.png
#   inflating: Binary_Classification_Apnea/non_apnea/31658.png
#   inflating: Binary_Classification_Apnea/non_apnea/31659.png
#   inflating: Binary_Classification_Apnea/non_apnea/31660.png
#   inflating: Binary_Classification_Apnea/non_apnea/31661.png
#   inflating: Binary_Classification_Apnea/non_apnea/31662.png
#   inflating: Binary_Classification_Apnea/non_apnea/31663.png
#   inflating: Binary_Classification_Apnea/non_apnea/31664.png
#   inflating: Binary_Classification_Apnea/non_apnea/31665.png
#   inflating: Binary_Classification_Apnea/non_apnea/31666.png
#   inflating: Binary_Classification_Apnea/non_apnea/31667.png
#   inflating: Binary_Classification_Apnea/non_apnea/31668.png
#   inflating: Binary_Classification_Apnea/non_apnea/31669.png
#   inflating: Binary_Classification_Apnea/non_apnea/31670.png
#   inflating: Binary_Classification_Apnea/non_apnea/31671.png
#   inflating: Binary_Classification_Apnea/non_apnea/31672.png
#   inflating: Binary_Classification_Apnea/non_apnea/31673.png
#   inflating: Binary_Classification_Apnea/non_apnea/31674.png
#   inflating: Binary_Classification_Apnea/non_apnea/31675.png
#   inflating: Binary_Classification_Apnea/non_apnea/31676.png
#   inflating: Binary_Classification_Apnea/non_apnea/31677.png
#   inflating: Binary_Classification_Apnea/non_apnea/31678.png
#   inflating: Binary_Classification_Apnea/non_apnea/31679.png
#   inflating: Binary_Classification_Apnea/non_apnea/31680.png
#   inflating: Binary_Classification_Apnea/non_apnea/31681.png
#   inflating: Binary_Classification_Apnea/non_apnea/31682.png
#   inflating: Binary_Classification_Apnea/non_apnea/31683.png
#   inflating: Binary_Classification_Apnea/non_apnea/31684.png
#   inflating: Binary_Classification_Apnea/non_apnea/31685.png
#   inflating: Binary_Classification_Apnea/non_apnea/31686.png
#   inflating: Binary_Classification_Apnea/non_apnea/31687.png
#   inflating: Binary_Classification_Apnea/non_apnea/31688.png
#   inflating: Binary_Classification_Apnea/non_apnea/31689.png
#   inflating: Binary_Classification_Apnea/non_apnea/31690.png
#   inflating: Binary_Classification_Apnea/non_apnea/31691.png
#   inflating: Binary_Classification_Apnea/non_apnea/31692.png
#   inflating: Binary_Classification_Apnea/non_apnea/31693.png
#   inflating: Binary_Classification_Apnea/non_apnea/31694.png
#   inflating: Binary_Classification_Apnea/non_apnea/31695.png
#   inflating: Binary_Classification_Apnea/non_apnea/31696.png
#   inflating: Binary_Classification_Apnea/non_apnea/31697.png
#   inflating: Binary_Classification_Apnea/non_apnea/31698.png
#   inflating: Binary_Classification_Apnea/non_apnea/31699.png
#   inflating: Binary_Classification_Apnea/non_apnea/31700.png
#   inflating: Binary_Classification_Apnea/non_apnea/31701.png
#   inflating: Binary_Classification_Apnea/non_apnea/31702.png
#   inflating: Binary_Classification_Apnea/non_apnea/31703.png
#   inflating: Binary_Classification_Apnea/non_apnea/31704.png
#   inflating: Binary_Classification_Apnea/non_apnea/31705.png
#   inflating: Binary_Classification_Apnea/non_apnea/31706.png
#   inflating: Binary_Classification_Apnea/non_apnea/31707.png
#   inflating: Binary_Classification_Apnea/non_apnea/31708.png
#   inflating: Binary_Classification_Apnea/non_apnea/31709.png
#   inflating: Binary_Classification_Apnea/non_apnea/31710.png
#   inflating: Binary_Classification_Apnea/non_apnea/31711.png
#   inflating: Binary_Classification_Apnea/non_apnea/31712.png
#   inflating: Binary_Classification_Apnea/non_apnea/31713.png
#   inflating: Binary_Classification_Apnea/non_apnea/31714.png
#   inflating: Binary_Classification_Apnea/non_apnea/31715.png
#   inflating: Binary_Classification_Apnea/non_apnea/31716.png
#   inflating: Binary_Classification_Apnea/non_apnea/31717.png
#   inflating: Binary_Classification_Apnea/non_apnea/31718.png
#   inflating: Binary_Classification_Apnea/non_apnea/31719.png
#   inflating: Binary_Classification_Apnea/non_apnea/31720.png
#   inflating: Binary_Classification_Apnea/non_apnea/31721.png
#   inflating: Binary_Classification_Apnea/non_apnea/31722.png
#   inflating: Binary_Classification_Apnea/non_apnea/31723.png
#   inflating: Binary_Classification_Apnea/non_apnea/31724.png
#   inflating: Binary_Classification_Apnea/non_apnea/31725.png
#   inflating: Binary_Classification_Apnea/non_apnea/31726.png
#   inflating: Binary_Classification_Apnea/non_apnea/31727.png
#   inflating: Binary_Classification_Apnea/non_apnea/31728.png
#   inflating: Binary_Classification_Apnea/non_apnea/31729.png
#   inflating: Binary_Classification_Apnea/non_apnea/31730.png
#   inflating: Binary_Classification_Apnea/non_apnea/31731.png
#   inflating: Binary_Classification_Apnea/non_apnea/31732.png
#   inflating: Binary_Classification_Apnea/non_apnea/31733.png
#   inflating: Binary_Classification_Apnea/non_apnea/31734.png
#   inflating: Binary_Classification_Apnea/non_apnea/31735.png
#   inflating: Binary_Classification_Apnea/non_apnea/31736.png
#   inflating: Binary_Classification_Apnea/non_apnea/31737.png
#   inflating: Binary_Classification_Apnea/non_apnea/31738.png
#   inflating: Binary_Classification_Apnea/non_apnea/31739.png
#   inflating: Binary_Classification_Apnea/non_apnea/31740.png
#   inflating: Binary_Classification_Apnea/non_apnea/31741.png
#   inflating: Binary_Classification_Apnea/non_apnea/31742.png
#   inflating: Binary_Classification_Apnea/non_apnea/31743.png
#   inflating: Binary_Classification_Apnea/non_apnea/31744.png
#   inflating: Binary_Classification_Apnea/non_apnea/31745.png
#   inflating: Binary_Classification_Apnea/non_apnea/31746.png
#   inflating: Binary_Classification_Apnea/non_apnea/31747.png
#   inflating: Binary_Classification_Apnea/non_apnea/31748.png
#   inflating: Binary_Classification_Apnea/non_apnea/31749.png
#   inflating: Binary_Classification_Apnea/non_apnea/31750.png
#   inflating: Binary_Classification_Apnea/non_apnea/31751.png
#   inflating: Binary_Classification_Apnea/non_apnea/31752.png
#   inflating: Binary_Classification_Apnea/non_apnea/31753.png
#   inflating: Binary_Classification_Apnea/non_apnea/31754.png
#   inflating: Binary_Classification_Apnea/non_apnea/31755.png
#   inflating: Binary_Classification_Apnea/non_apnea/31756.png
#   inflating: Binary_Classification_Apnea/non_apnea/31757.png
#   inflating: Binary_Classification_Apnea/non_apnea/31758.png
#   inflating: Binary_Classification_Apnea/non_apnea/31759.png
#   inflating: Binary_Classification_Apnea/non_apnea/31760.png
#   inflating: Binary_Classification_Apnea/non_apnea/31761.png
#   inflating: Binary_Classification_Apnea/non_apnea/31762.png
#   inflating: Binary_Classification_Apnea/non_apnea/31763.png
#   inflating: Binary_Classification_Apnea/non_apnea/31764.png
#   inflating: Binary_Classification_Apnea/non_apnea/31765.png
#   inflating: Binary_Classification_Apnea/non_apnea/31766.png
#   inflating: Binary_Classification_Apnea/non_apnea/31767.png
#   inflating: Binary_Classification_Apnea/non_apnea/31768.png
#   inflating: Binary_Classification_Apnea/non_apnea/31769.png
#   inflating: Binary_Classification_Apnea/non_apnea/31770.png
#   inflating: Binary_Classification_Apnea/non_apnea/31771.png
#   inflating: Binary_Classification_Apnea/non_apnea/31772.png
#   inflating: Binary_Classification_Apnea/non_apnea/31773.png
#   inflating: Binary_Classification_Apnea/non_apnea/31774.png
#   inflating: Binary_Classification_Apnea/non_apnea/31775.png
#   inflating: Binary_Classification_Apnea/non_apnea/31776.png
#   inflating: Binary_Classification_Apnea/non_apnea/31777.png
#   inflating: Binary_Classification_Apnea/non_apnea/31778.png
#   inflating: Binary_Classification_Apnea/non_apnea/31779.png
#   inflating: Binary_Classification_Apnea/non_apnea/31780.png
#   inflating: Binary_Classification_Apnea/non_apnea/31781.png
#   inflating: Binary_Classification_Apnea/non_apnea/31782.png
#   inflating: Binary_Classification_Apnea/non_apnea/31783.png
#   inflating: Binary_Classification_Apnea/non_apnea/31784.png
#   inflating: Binary_Classification_Apnea/non_apnea/31785.png
#   inflating: Binary_Classification_Apnea/non_apnea/31786.png
#   inflating: Binary_Classification_Apnea/non_apnea/31787.png
#   inflating: Binary_Classification_Apnea/non_apnea/31788.png
#   inflating: Binary_Classification_Apnea/non_apnea/31789.png
#   inflating: Binary_Classification_Apnea/non_apnea/31790.png
#   inflating: Binary_Classification_Apnea/non_apnea/31791.png
#   inflating: Binary_Classification_Apnea/non_apnea/31792.png
#   inflating: Binary_Classification_Apnea/non_apnea/31793.png
#   inflating: Binary_Classification_Apnea/non_apnea/31794.png
#   inflating: Binary_Classification_Apnea/non_apnea/31795.png
#   inflating: Binary_Classification_Apnea/non_apnea/31796.png
#   inflating: Binary_Classification_Apnea/non_apnea/31797.png
#   inflating: Binary_Classification_Apnea/non_apnea/31798.png
#   inflating: Binary_Classification_Apnea/non_apnea/31799.png
#   inflating: Binary_Classification_Apnea/non_apnea/31800.png
#   inflating: Binary_Classification_Apnea/non_apnea/31801.png
#   inflating: Binary_Classification_Apnea/non_apnea/31802.png
#   inflating: Binary_Classification_Apnea/non_apnea/31803.png
#   inflating: Binary_Classification_Apnea/non_apnea/31804.png
#   inflating: Binary_Classification_Apnea/non_apnea/31805.png
#   inflating: Binary_Classification_Apnea/non_apnea/31806.png
#   inflating: Binary_Classification_Apnea/non_apnea/31807.png
#   inflating: Binary_Classification_Apnea/non_apnea/31808.png
#   inflating: Binary_Classification_Apnea/non_apnea/31809.png
#   inflating: Binary_Classification_Apnea/non_apnea/31810.png
#   inflating: Binary_Classification_Apnea/non_apnea/31811.png
#   inflating: Binary_Classification_Apnea/non_apnea/31812.png
#   inflating: Binary_Classification_Apnea/non_apnea/31813.png
#   inflating: Binary_Classification_Apnea/non_apnea/31814.png
#   inflating: Binary_Classification_Apnea/non_apnea/31815.png
#   inflating: Binary_Classification_Apnea/non_apnea/31816.png
#   inflating: Binary_Classification_Apnea/non_apnea/31817.png
#   inflating: Binary_Classification_Apnea/non_apnea/31818.png
#   inflating: Binary_Classification_Apnea/non_apnea/31819.png
#   inflating: Binary_Classification_Apnea/non_apnea/31820.png
#   inflating: Binary_Classification_Apnea/non_apnea/31821.png
#   inflating: Binary_Classification_Apnea/non_apnea/31822.png
#   inflating: Binary_Classification_Apnea/non_apnea/31823.png
#   inflating: Binary_Classification_Apnea/non_apnea/31824.png
#   inflating: Binary_Classification_Apnea/non_apnea/31825.png
#   inflating: Binary_Classification_Apnea/non_apnea/31826.png
#   inflating: Binary_Classification_Apnea/non_apnea/31827.png
#   inflating: Binary_Classification_Apnea/non_apnea/31828.png
#   inflating: Binary_Classification_Apnea/non_apnea/31829.png
#   inflating: Binary_Classification_Apnea/non_apnea/31830.png
#   inflating: Binary_Classification_Apnea/non_apnea/31831.png
#   inflating: Binary_Classification_Apnea/non_apnea/31832.png
#   inflating: Binary_Classification_Apnea/non_apnea/31833.png
#   inflating: Binary_Classification_Apnea/non_apnea/31834.png
#   inflating: Binary_Classification_Apnea/non_apnea/31835.png
#   inflating: Binary_Classification_Apnea/non_apnea/31836.png
#   inflating: Binary_Classification_Apnea/non_apnea/31837.png
#   inflating: Binary_Classification_Apnea/non_apnea/31838.png
#   inflating: Binary_Classification_Apnea/non_apnea/31839.png
#   inflating: Binary_Classification_Apnea/non_apnea/31840.png
#   inflating: Binary_Classification_Apnea/non_apnea/31841.png
#   inflating: Binary_Classification_Apnea/non_apnea/31842.png
#   inflating: Binary_Classification_Apnea/non_apnea/31843.png
#   inflating: Binary_Classification_Apnea/non_apnea/31844.png
#   inflating: Binary_Classification_Apnea/non_apnea/31845.png
#   inflating: Binary_Classification_Apnea/non_apnea/31846.png
#   inflating: Binary_Classification_Apnea/non_apnea/31847.png
#   inflating: Binary_Classification_Apnea/non_apnea/31848.png
#   inflating: Binary_Classification_Apnea/non_apnea/31850.png
#   inflating: Binary_Classification_Apnea/non_apnea/31851.png
#   inflating: Binary_Classification_Apnea/non_apnea/31852.png
#   inflating: Binary_Classification_Apnea/non_apnea/31853.png
#   inflating: Binary_Classification_Apnea/non_apnea/31854.png
#   inflating: Binary_Classification_Apnea/non_apnea/31855.png
#   inflating: Binary_Classification_Apnea/non_apnea/31856.png
#   inflating: Binary_Classification_Apnea/non_apnea/31857.png
#   inflating: Binary_Classification_Apnea/non_apnea/31858.png
#   inflating: Binary_Classification_Apnea/non_apnea/31859.png
#   inflating: Binary_Classification_Apnea/non_apnea/31860.png
#   inflating: Binary_Classification_Apnea/non_apnea/31861.png
#   inflating: Binary_Classification_Apnea/non_apnea/31862.png
#   inflating: Binary_Classification_Apnea/non_apnea/31863.png
#   inflating: Binary_Classification_Apnea/non_apnea/31864.png
#   inflating: Binary_Classification_Apnea/non_apnea/31865.png
#   inflating: Binary_Classification_Apnea/non_apnea/31866.png
#   inflating: Binary_Classification_Apnea/non_apnea/31867.png
#   inflating: Binary_Classification_Apnea/non_apnea/31868.png
#   inflating: Binary_Classification_Apnea/non_apnea/31869.png
#   inflating: Binary_Classification_Apnea/non_apnea/31870.png
#   inflating: Binary_Classification_Apnea/non_apnea/31871.png
#   inflating: Binary_Classification_Apnea/non_apnea/31872.png
#   inflating: Binary_Classification_Apnea/non_apnea/31873.png
#   inflating: Binary_Classification_Apnea/non_apnea/31874.png
#   inflating: Binary_Classification_Apnea/non_apnea/31875.png
#   inflating: Binary_Classification_Apnea/non_apnea/31876.png
#   inflating: Binary_Classification_Apnea/non_apnea/31877.png
#   inflating: Binary_Classification_Apnea/non_apnea/31878.png
#   inflating: Binary_Classification_Apnea/non_apnea/31879.png
#   inflating: Binary_Classification_Apnea/non_apnea/31880.png
#   inflating: Binary_Classification_Apnea/non_apnea/31881.png
#   inflating: Binary_Classification_Apnea/non_apnea/31882.png
#   inflating: Binary_Classification_Apnea/non_apnea/31883.png
#   inflating: Binary_Classification_Apnea/non_apnea/31884.png
#   inflating: Binary_Classification_Apnea/non_apnea/31885.png
#   inflating: Binary_Classification_Apnea/non_apnea/31886.png
#   inflating: Binary_Classification_Apnea/non_apnea/31887.png
#   inflating: Binary_Classification_Apnea/non_apnea/31888.png
#   inflating: Binary_Classification_Apnea/non_apnea/31889.png
#   inflating: Binary_Classification_Apnea/non_apnea/31890.png
#   inflating: Binary_Classification_Apnea/non_apnea/31891.png
#   inflating: Binary_Classification_Apnea/non_apnea/31892.png
#   inflating: Binary_Classification_Apnea/non_apnea/31893.png
#   inflating: Binary_Classification_Apnea/non_apnea/31894.png
#   inflating: Binary_Classification_Apnea/non_apnea/31895.png
#   inflating: Binary_Classification_Apnea/non_apnea/31896.png
#   inflating: Binary_Classification_Apnea/non_apnea/31897.png
#   inflating: Binary_Classification_Apnea/non_apnea/31898.png
#   inflating: Binary_Classification_Apnea/non_apnea/31899.png
#   inflating: Binary_Classification_Apnea/non_apnea/31900.png
#   inflating: Binary_Classification_Apnea/non_apnea/31901.png
#   inflating: Binary_Classification_Apnea/non_apnea/31902.png
#   inflating: Binary_Classification_Apnea/non_apnea/31903.png
#   inflating: Binary_Classification_Apnea/non_apnea/31904.png
#   inflating: Binary_Classification_Apnea/non_apnea/31905.png
#   inflating: Binary_Classification_Apnea/non_apnea/31906.png
#   inflating: Binary_Classification_Apnea/non_apnea/31907.png
#   inflating: Binary_Classification_Apnea/non_apnea/31908.png
#   inflating: Binary_Classification_Apnea/non_apnea/31909.png
#   inflating: Binary_Classification_Apnea/non_apnea/31910.png
#   inflating: Binary_Classification_Apnea/non_apnea/31911.png
#   inflating: Binary_Classification_Apnea/non_apnea/31912.png
#   inflating: Binary_Classification_Apnea/non_apnea/31913.png
#   inflating: Binary_Classification_Apnea/non_apnea/31914.png
#   inflating: Binary_Classification_Apnea/non_apnea/31915.png
#   inflating: Binary_Classification_Apnea/non_apnea/31916.png
#   inflating: Binary_Classification_Apnea/non_apnea/31917.png
#   inflating: Binary_Classification_Apnea/non_apnea/31918.png
#   inflating: Binary_Classification_Apnea/non_apnea/31919.png
#   inflating: Binary_Classification_Apnea/non_apnea/31920.png
#   inflating: Binary_Classification_Apnea/non_apnea/31921.png
#   inflating: Binary_Classification_Apnea/non_apnea/31922.png
#   inflating: Binary_Classification_Apnea/non_apnea/31923.png
#   inflating: Binary_Classification_Apnea/non_apnea/31924.png
#   inflating: Binary_Classification_Apnea/non_apnea/31925.png
#   inflating: Binary_Classification_Apnea/non_apnea/31926.png
#   inflating: Binary_Classification_Apnea/non_apnea/31927.png
#   inflating: Binary_Classification_Apnea/non_apnea/31928.png
#   inflating: Binary_Classification_Apnea/non_apnea/31929.png
#   inflating: Binary_Classification_Apnea/non_apnea/31930.png
#   inflating: Binary_Classification_Apnea/non_apnea/31931.png
#   inflating: Binary_Classification_Apnea/non_apnea/31932.png
#   inflating: Binary_Classification_Apnea/non_apnea/31933.png
#   inflating: Binary_Classification_Apnea/non_apnea/31934.png
#   inflating: Binary_Classification_Apnea/non_apnea/31935.png
#   inflating: Binary_Classification_Apnea/non_apnea/31936.png
#   inflating: Binary_Classification_Apnea/non_apnea/31937.png
#   inflating: Binary_Classification_Apnea/non_apnea/31938.png
#   inflating: Binary_Classification_Apnea/non_apnea/31939.png
#   inflating: Binary_Classification_Apnea/non_apnea/31940.png
#   inflating: Binary_Classification_Apnea/non_apnea/31941.png
#   inflating: Binary_Classification_Apnea/non_apnea/31942.png
#   inflating: Binary_Classification_Apnea/non_apnea/31943.png
#   inflating: Binary_Classification_Apnea/non_apnea/31944.png
#   inflating: Binary_Classification_Apnea/non_apnea/31945.png
#   inflating: Binary_Classification_Apnea/non_apnea/31946.png
#   inflating: Binary_Classification_Apnea/non_apnea/31947.png
#   inflating: Binary_Classification_Apnea/non_apnea/31948.png
#   inflating: Binary_Classification_Apnea/non_apnea/31949.png
#   inflating: Binary_Classification_Apnea/non_apnea/31950.png
#   inflating: Binary_Classification_Apnea/non_apnea/31951.png
#   inflating: Binary_Classification_Apnea/non_apnea/31952.png
#   inflating: Binary_Classification_Apnea/non_apnea/31953.png
#   inflating: Binary_Classification_Apnea/non_apnea/31954.png
#   inflating: Binary_Classification_Apnea/non_apnea/31955.png
#   inflating: Binary_Classification_Apnea/non_apnea/31956.png
#   inflating: Binary_Classification_Apnea/non_apnea/31957.png
#   inflating: Binary_Classification_Apnea/non_apnea/31958.png
#   inflating: Binary_Classification_Apnea/non_apnea/31959.png
#   inflating: Binary_Classification_Apnea/non_apnea/31960.png
#   inflating: Binary_Classification_Apnea/non_apnea/31961.png
#   inflating: Binary_Classification_Apnea/non_apnea/31962.png
#   inflating: Binary_Classification_Apnea/non_apnea/31963.png
#   inflating: Binary_Classification_Apnea/non_apnea/31964.png
#   inflating: Binary_Classification_Apnea/non_apnea/31965.png
#   inflating: Binary_Classification_Apnea/non_apnea/31966.png
#   inflating: Binary_Classification_Apnea/non_apnea/31967.png
#   inflating: Binary_Classification_Apnea/non_apnea/31968.png
#   inflating: Binary_Classification_Apnea/non_apnea/31969.png
#   inflating: Binary_Classification_Apnea/non_apnea/31970.png
#   inflating: Binary_Classification_Apnea/non_apnea/31971.png
#   inflating: Binary_Classification_Apnea/non_apnea/31972.png
#   inflating: Binary_Classification_Apnea/non_apnea/31973.png
#   inflating: Binary_Classification_Apnea/non_apnea/31974.png
#   inflating: Binary_Classification_Apnea/non_apnea/31975.png
#   inflating: Binary_Classification_Apnea/non_apnea/31976.png
#   inflating: Binary_Classification_Apnea/non_apnea/31977.png
#   inflating: Binary_Classification_Apnea/non_apnea/31978.png
#   inflating: Binary_Classification_Apnea/non_apnea/31979.png
#   inflating: Binary_Classification_Apnea/non_apnea/31980.png
#   inflating: Binary_Classification_Apnea/non_apnea/31981.png
#   inflating: Binary_Classification_Apnea/non_apnea/31982.png
#   inflating: Binary_Classification_Apnea/non_apnea/31983.png
#   inflating: Binary_Classification_Apnea/non_apnea/31984.png
#   inflating: Binary_Classification_Apnea/non_apnea/31985.png
#   inflating: Binary_Classification_Apnea/non_apnea/31986.png
#   inflating: Binary_Classification_Apnea/non_apnea/31987.png
#   inflating: Binary_Classification_Apnea/non_apnea/31988.png
#   inflating: Binary_Classification_Apnea/non_apnea/31989.png
#   inflating: Binary_Classification_Apnea/non_apnea/31990.png
#   inflating: Binary_Classification_Apnea/non_apnea/31991.png
#   inflating: Binary_Classification_Apnea/non_apnea/31992.png
#   inflating: Binary_Classification_Apnea/non_apnea/31993.png
#   inflating: Binary_Classification_Apnea/non_apnea/31994.png
#   inflating: Binary_Classification_Apnea/non_apnea/31995.png
#   inflating: Binary_Classification_Apnea/non_apnea/31996.png
#   inflating: Binary_Classification_Apnea/non_apnea/31997.png
#   inflating: Binary_Classification_Apnea/non_apnea/31998.png
#   inflating: Binary_Classification_Apnea/non_apnea/31999.png
#   inflating: Binary_Classification_Apnea/non_apnea/32000.png
#   inflating: Binary_Classification_Apnea/non_apnea/32001.png
#   inflating: Binary_Classification_Apnea/non_apnea/32002.png
#   inflating: Binary_Classification_Apnea/non_apnea/32003.png
#   inflating: Binary_Classification_Apnea/non_apnea/32004.png
#   inflating: Binary_Classification_Apnea/non_apnea/32005.png
#   inflating: Binary_Classification_Apnea/non_apnea/32006.png
#   inflating: Binary_Classification_Apnea/non_apnea/32007.png
#   inflating: Binary_Classification_Apnea/non_apnea/32008.png
#   inflating: Binary_Classification_Apnea/non_apnea/32009.png
#   inflating: Binary_Classification_Apnea/non_apnea/32010.png
#   inflating: Binary_Classification_Apnea/non_apnea/32011.png
#   inflating: Binary_Classification_Apnea/non_apnea/32012.png
#   inflating: Binary_Classification_Apnea/non_apnea/32013.png
#   inflating: Binary_Classification_Apnea/non_apnea/32014.png
#   inflating: Binary_Classification_Apnea/non_apnea/32015.png
#   inflating: Binary_Classification_Apnea/non_apnea/32016.png
#   inflating: Binary_Classification_Apnea/non_apnea/32017.png
#   inflating: Binary_Classification_Apnea/non_apnea/32018.png
#   inflating: Binary_Classification_Apnea/non_apnea/32019.png
#   inflating: Binary_Classification_Apnea/non_apnea/32020.png
#   inflating: Binary_Classification_Apnea/non_apnea/32021.png
#   inflating: Binary_Classification_Apnea/non_apnea/32022.png
#   inflating: Binary_Classification_Apnea/non_apnea/32023.png
#   inflating: Binary_Classification_Apnea/non_apnea/32024.png
#   inflating: Binary_Classification_Apnea/non_apnea/32025.png
#   inflating: Binary_Classification_Apnea/non_apnea/32026.png
#   inflating: Binary_Classification_Apnea/non_apnea/32027.png
#   inflating: Binary_Classification_Apnea/non_apnea/32028.png
#   inflating: Binary_Classification_Apnea/non_apnea/32029.png
#   inflating: Binary_Classification_Apnea/non_apnea/32030.png
#   inflating: Binary_Classification_Apnea/non_apnea/32031.png
#   inflating: Binary_Classification_Apnea/non_apnea/32032.png
#   inflating: Binary_Classification_Apnea/non_apnea/32033.png
#   inflating: Binary_Classification_Apnea/non_apnea/32034.png
#   inflating: Binary_Classification_Apnea/non_apnea/32035.png
#   inflating: Binary_Classification_Apnea/non_apnea/32036.png
#   inflating: Binary_Classification_Apnea/non_apnea/32037.png
#   inflating: Binary_Classification_Apnea/non_apnea/32038.png
#   inflating: Binary_Classification_Apnea/non_apnea/32039.png
#   inflating: Binary_Classification_Apnea/non_apnea/32040.png
#   inflating: Binary_Classification_Apnea/non_apnea/32041.png
#   inflating: Binary_Classification_Apnea/non_apnea/32042.png
#   inflating: Binary_Classification_Apnea/non_apnea/32043.png
#   inflating: Binary_Classification_Apnea/non_apnea/32044.png
#   inflating: Binary_Classification_Apnea/non_apnea/32045.png
#   inflating: Binary_Classification_Apnea/non_apnea/32046.png
#   inflating: Binary_Classification_Apnea/non_apnea/32047.png
#   inflating: Binary_Classification_Apnea/non_apnea/32048.png
#   inflating: Binary_Classification_Apnea/non_apnea/32049.png
#   inflating: Binary_Classification_Apnea/non_apnea/32050.png
#   inflating: Binary_Classification_Apnea/non_apnea/32051.png
#   inflating: Binary_Classification_Apnea/non_apnea/32052.png
#   inflating: Binary_Classification_Apnea/non_apnea/32053.png
#   inflating: Binary_Classification_Apnea/non_apnea/32054.png
#   inflating: Binary_Classification_Apnea/non_apnea/32055.png
#   inflating: Binary_Classification_Apnea/non_apnea/32056.png
#   inflating: Binary_Classification_Apnea/non_apnea/32057.png
#   inflating: Binary_Classification_Apnea/non_apnea/32058.png
#   inflating: Binary_Classification_Apnea/non_apnea/32059.png
#   inflating: Binary_Classification_Apnea/non_apnea/32060.png
#   inflating: Binary_Classification_Apnea/non_apnea/32061.png
#   inflating: Binary_Classification_Apnea/non_apnea/32062.png
#   inflating: Binary_Classification_Apnea/non_apnea/32063.png
#   inflating: Binary_Classification_Apnea/non_apnea/32064.png
#   inflating: Binary_Classification_Apnea/non_apnea/32065.png
#   inflating: Binary_Classification_Apnea/non_apnea/32066.png
#   inflating: Binary_Classification_Apnea/non_apnea/32067.png
#   inflating: Binary_Classification_Apnea/non_apnea/32068.png
#   inflating: Binary_Classification_Apnea/non_apnea/32069.png
#   inflating: Binary_Classification_Apnea/non_apnea/32070.png
#   inflating: Binary_Classification_Apnea/non_apnea/32071.png
#   inflating: Binary_Classification_Apnea/non_apnea/32072.png
#   inflating: Binary_Classification_Apnea/non_apnea/32073.png
#   inflating: Binary_Classification_Apnea/non_apnea/32074.png
#   inflating: Binary_Classification_Apnea/non_apnea/32075.png
#   inflating: Binary_Classification_Apnea/non_apnea/32076.png
#   inflating: Binary_Classification_Apnea/non_apnea/32077.png
#   inflating: Binary_Classification_Apnea/non_apnea/32078.png
#   inflating: Binary_Classification_Apnea/non_apnea/32079.png
#   inflating: Binary_Classification_Apnea/non_apnea/32080.png
#   inflating: Binary_Classification_Apnea/non_apnea/32081.png
#   inflating: Binary_Classification_Apnea/non_apnea/32082.png
#   inflating: Binary_Classification_Apnea/non_apnea/32083.png
#   inflating: Binary_Classification_Apnea/non_apnea/32084.png
#   inflating: Binary_Classification_Apnea/non_apnea/32085.png
#   inflating: Binary_Classification_Apnea/non_apnea/32086.png
#   inflating: Binary_Classification_Apnea/non_apnea/32087.png
#   inflating: Binary_Classification_Apnea/non_apnea/32088.png
#   inflating: Binary_Classification_Apnea/non_apnea/32089.png
#   inflating: Binary_Classification_Apnea/non_apnea/32090.png
#   inflating: Binary_Classification_Apnea/non_apnea/32091.png
#   inflating: Binary_Classification_Apnea/non_apnea/32092.png
#   inflating: Binary_Classification_Apnea/non_apnea/32093.png
#   inflating: Binary_Classification_Apnea/non_apnea/32094.png
#   inflating: Binary_Classification_Apnea/non_apnea/32095.png
#   inflating: Binary_Classification_Apnea/non_apnea/32096.png
#   inflating: Binary_Classification_Apnea/non_apnea/32097.png
#   inflating: Binary_Classification_Apnea/non_apnea/32098.png
#   inflating: Binary_Classification_Apnea/non_apnea/32099.png
#   inflating: Binary_Classification_Apnea/non_apnea/32100.png
#   inflating: Binary_Classification_Apnea/non_apnea/32101.png
#   inflating: Binary_Classification_Apnea/non_apnea/32102.png
#   inflating: Binary_Classification_Apnea/non_apnea/32103.png
#   inflating: Binary_Classification_Apnea/non_apnea/32104.png
#   inflating: Binary_Classification_Apnea/non_apnea/32105.png
#   inflating: Binary_Classification_Apnea/non_apnea/32106.png
#   inflating: Binary_Classification_Apnea/non_apnea/32107.png
#   inflating: Binary_Classification_Apnea/non_apnea/32108.png
#   inflating: Binary_Classification_Apnea/non_apnea/32109.png
#   inflating: Binary_Classification_Apnea/non_apnea/32110.png
#   inflating: Binary_Classification_Apnea/non_apnea/32111.png
#   inflating: Binary_Classification_Apnea/non_apnea/32112.png
#   inflating: Binary_Classification_Apnea/non_apnea/32113.png
#   inflating: Binary_Classification_Apnea/non_apnea/32114.png
#   inflating: Binary_Classification_Apnea/non_apnea/32115.png
#   inflating: Binary_Classification_Apnea/non_apnea/32116.png
#   inflating: Binary_Classification_Apnea/non_apnea/32117.png
#   inflating: Binary_Classification_Apnea/non_apnea/32118.png
#   inflating: Binary_Classification_Apnea/non_apnea/32119.png
#   inflating: Binary_Classification_Apnea/non_apnea/32120.png
#   inflating: Binary_Classification_Apnea/non_apnea/32121.png
#   inflating: Binary_Classification_Apnea/non_apnea/32122.png
#   inflating: Binary_Classification_Apnea/non_apnea/32123.png
#   inflating: Binary_Classification_Apnea/non_apnea/32124.png
#   inflating: Binary_Classification_Apnea/non_apnea/32125.png
#   inflating: Binary_Classification_Apnea/non_apnea/32126.png
#   inflating: Binary_Classification_Apnea/non_apnea/32127.png
#   inflating: Binary_Classification_Apnea/non_apnea/32128.png
#   inflating: Binary_Classification_Apnea/non_apnea/32129.png
#   inflating: Binary_Classification_Apnea/non_apnea/32130.png
#   inflating: Binary_Classification_Apnea/non_apnea/32131.png
#   inflating: Binary_Classification_Apnea/non_apnea/32132.png
#   inflating: Binary_Classification_Apnea/non_apnea/32133.png
#   inflating: Binary_Classification_Apnea/non_apnea/32134.png
#   inflating: Binary_Classification_Apnea/non_apnea/32135.png
#   inflating: Binary_Classification_Apnea/non_apnea/32136.png
#   inflating: Binary_Classification_Apnea/non_apnea/32137.png
#   inflating: Binary_Classification_Apnea/non_apnea/32138.png
#   inflating: Binary_Classification_Apnea/non_apnea/32139.png
#   inflating: Binary_Classification_Apnea/non_apnea/32140.png
#   inflating: Binary_Classification_Apnea/non_apnea/32141.png
#   inflating: Binary_Classification_Apnea/non_apnea/32142.png
#   inflating: Binary_Classification_Apnea/non_apnea/32143.png
#   inflating: Binary_Classification_Apnea/non_apnea/32144.png
#   inflating: Binary_Classification_Apnea/non_apnea/32145.png
#   inflating: Binary_Classification_Apnea/non_apnea/32146.png
#   inflating: Binary_Classification_Apnea/non_apnea/32147.png
#   inflating: Binary_Classification_Apnea/non_apnea/32148.png
#   inflating: Binary_Classification_Apnea/non_apnea/32149.png
#   inflating: Binary_Classification_Apnea/non_apnea/32150.png
#   inflating: Binary_Classification_Apnea/non_apnea/32151.png
#   inflating: Binary_Classification_Apnea/non_apnea/32152.png
#   inflating: Binary_Classification_Apnea/non_apnea/32153.png
#   inflating: Binary_Classification_Apnea/non_apnea/32154.png
#   inflating: Binary_Classification_Apnea/non_apnea/32155.png
#   inflating: Binary_Classification_Apnea/non_apnea/32156.png
#   inflating: Binary_Classification_Apnea/non_apnea/32157.png
#   inflating: Binary_Classification_Apnea/non_apnea/32158.png
#   inflating: Binary_Classification_Apnea/non_apnea/32159.png
#   inflating: Binary_Classification_Apnea/non_apnea/32160.png
#   inflating: Binary_Classification_Apnea/non_apnea/32161.png
#   inflating: Binary_Classification_Apnea/non_apnea/32162.png
#   inflating: Binary_Classification_Apnea/non_apnea/32163.png
#   inflating: Binary_Classification_Apnea/non_apnea/32164.png
#   inflating: Binary_Classification_Apnea/non_apnea/32165.png
#   inflating: Binary_Classification_Apnea/non_apnea/32166.png
#   inflating: Binary_Classification_Apnea/non_apnea/32167.png
#   inflating: Binary_Classification_Apnea/non_apnea/32168.png
#   inflating: Binary_Classification_Apnea/non_apnea/32169.png
#   inflating: Binary_Classification_Apnea/non_apnea/32170.png
#   inflating: Binary_Classification_Apnea/non_apnea/32171.png
#   inflating: Binary_Classification_Apnea/non_apnea/32172.png
#   inflating: Binary_Classification_Apnea/non_apnea/32173.png
#   inflating: Binary_Classification_Apnea/non_apnea/32174.png
#   inflating: Binary_Classification_Apnea/non_apnea/32175.png
#   inflating: Binary_Classification_Apnea/non_apnea/32176.png
#   inflating: Binary_Classification_Apnea/non_apnea/32177.png
#   inflating: Binary_Classification_Apnea/non_apnea/32178.png
#   inflating: Binary_Classification_Apnea/non_apnea/32179.png
#   inflating: Binary_Classification_Apnea/non_apnea/32180.png
#   inflating: Binary_Classification_Apnea/non_apnea/32181.png
#   inflating: Binary_Classification_Apnea/non_apnea/32182.png
#   inflating: Binary_Classification_Apnea/non_apnea/32183.png
#   inflating: Binary_Classification_Apnea/non_apnea/32184.png
#   inflating: Binary_Classification_Apnea/non_apnea/32185.png
#   inflating: Binary_Classification_Apnea/non_apnea/32186.png
#   inflating: Binary_Classification_Apnea/non_apnea/32187.png
#   inflating: Binary_Classification_Apnea/non_apnea/32188.png
#   inflating: Binary_Classification_Apnea/non_apnea/32189.png
#   inflating: Binary_Classification_Apnea/non_apnea/32190.png
#   inflating: Binary_Classification_Apnea/non_apnea/32191.png
#   inflating: Binary_Classification_Apnea/non_apnea/32192.png
#   inflating: Binary_Classification_Apnea/non_apnea/32193.png
#   inflating: Binary_Classification_Apnea/non_apnea/32194.png
#   inflating: Binary_Classification_Apnea/non_apnea/32195.png
#   inflating: Binary_Classification_Apnea/non_apnea/32196.png
#   inflating: Binary_Classification_Apnea/non_apnea/32197.png
#   inflating: Binary_Classification_Apnea/non_apnea/32198.png
#   inflating: Binary_Classification_Apnea/non_apnea/32199.png
#   inflating: Binary_Classification_Apnea/non_apnea/32200.png
#   inflating: Binary_Classification_Apnea/non_apnea/32201.png
#   inflating: Binary_Classification_Apnea/non_apnea/32202.png
#   inflating: Binary_Classification_Apnea/non_apnea/32203.png
#   inflating: Binary_Classification_Apnea/non_apnea/32204.png
#   inflating: Binary_Classification_Apnea/non_apnea/32205.png
#   inflating: Binary_Classification_Apnea/non_apnea/32206.png
#   inflating: Binary_Classification_Apnea/non_apnea/32207.png
#   inflating: Binary_Classification_Apnea/non_apnea/32208.png
#   inflating: Binary_Classification_Apnea/non_apnea/32209.png
#   inflating: Binary_Classification_Apnea/non_apnea/32210.png
#   inflating: Binary_Classification_Apnea/non_apnea/32211.png
#   inflating: Binary_Classification_Apnea/non_apnea/32212.png
#   inflating: Binary_Classification_Apnea/non_apnea/32213.png
#   inflating: Binary_Classification_Apnea/non_apnea/32214.png
#   inflating: Binary_Classification_Apnea/non_apnea/32215.png
#   inflating: Binary_Classification_Apnea/non_apnea/32216.png
#   inflating: Binary_Classification_Apnea/non_apnea/32217.png
#   inflating: Binary_Classification_Apnea/non_apnea/32218.png
#   inflating: Binary_Classification_Apnea/non_apnea/32219.png
#   inflating: Binary_Classification_Apnea/non_apnea/32220.png
#   inflating: Binary_Classification_Apnea/non_apnea/32221.png
#   inflating: Binary_Classification_Apnea/non_apnea/32222.png
#   inflating: Binary_Classification_Apnea/non_apnea/32223.png
#   inflating: Binary_Classification_Apnea/non_apnea/32224.png
#   inflating: Binary_Classification_Apnea/non_apnea/32225.png
#   inflating: Binary_Classification_Apnea/non_apnea/32226.png
#   inflating: Binary_Classification_Apnea/non_apnea/32227.png
#   inflating: Binary_Classification_Apnea/non_apnea/32228.png
#   inflating: Binary_Classification_Apnea/non_apnea/32229.png
#   inflating: Binary_Classification_Apnea/non_apnea/32230.png
#   inflating: Binary_Classification_Apnea/non_apnea/32231.png
#   inflating: Binary_Classification_Apnea/non_apnea/32232.png
#   inflating: Binary_Classification_Apnea/non_apnea/32233.png
#   inflating: Binary_Classification_Apnea/non_apnea/32234.png
#   inflating: Binary_Classification_Apnea/non_apnea/32235.png
#   inflating: Binary_Classification_Apnea/non_apnea/32236.png
#   inflating: Binary_Classification_Apnea/non_apnea/32237.png
#   inflating: Binary_Classification_Apnea/non_apnea/32238.png
#   inflating: Binary_Classification_Apnea/non_apnea/32239.png
#   inflating: Binary_Classification_Apnea/non_apnea/32240.png
#   inflating: Binary_Classification_Apnea/non_apnea/32241.png
#   inflating: Binary_Classification_Apnea/non_apnea/32242.png
#   inflating: Binary_Classification_Apnea/non_apnea/32243.png
#   inflating: Binary_Classification_Apnea/non_apnea/32244.png
#   inflating: Binary_Classification_Apnea/non_apnea/32245.png
#   inflating: Binary_Classification_Apnea/non_apnea/32246.png
#   inflating: Binary_Classification_Apnea/non_apnea/32247.png
#   inflating: Binary_Classification_Apnea/non_apnea/32248.png
#   inflating: Binary_Classification_Apnea/non_apnea/32249.png
#   inflating: Binary_Classification_Apnea/non_apnea/32250.png
#   inflating: Binary_Classification_Apnea/non_apnea/32251.png
#   inflating: Binary_Classification_Apnea/non_apnea/32252.png
#   inflating: Binary_Classification_Apnea/non_apnea/32253.png
#   inflating: Binary_Classification_Apnea/non_apnea/32254.png
#   inflating: Binary_Classification_Apnea/non_apnea/32255.png
#   inflating: Binary_Classification_Apnea/non_apnea/32256.png
#   inflating: Binary_Classification_Apnea/non_apnea/32257.png
#   inflating: Binary_Classification_Apnea/non_apnea/32258.png
#   inflating: Binary_Classification_Apnea/non_apnea/32259.png
#   inflating: Binary_Classification_Apnea/non_apnea/32260.png
#   inflating: Binary_Classification_Apnea/non_apnea/32261.png
#   inflating: Binary_Classification_Apnea/non_apnea/32262.png
#   inflating: Binary_Classification_Apnea/non_apnea/32263.png
#   inflating: Binary_Classification_Apnea/non_apnea/32264.png
#   inflating: Binary_Classification_Apnea/non_apnea/32265.png
#   inflating: Binary_Classification_Apnea/non_apnea/32266.png
#   inflating: Binary_Classification_Apnea/non_apnea/32267.png
#   inflating: Binary_Classification_Apnea/non_apnea/32268.png
#   inflating: Binary_Classification_Apnea/non_apnea/32269.png
#   inflating: Binary_Classification_Apnea/non_apnea/32270.png
#   inflating: Binary_Classification_Apnea/non_apnea/32271.png
#   inflating: Binary_Classification_Apnea/non_apnea/32272.png
#   inflating: Binary_Classification_Apnea/non_apnea/32273.png
#   inflating: Binary_Classification_Apnea/non_apnea/32274.png
#   inflating: Binary_Classification_Apnea/non_apnea/32275.png
#   inflating: Binary_Classification_Apnea/non_apnea/32276.png
#   inflating: Binary_Classification_Apnea/non_apnea/32277.png
#   inflating: Binary_Classification_Apnea/non_apnea/32278.png
#   inflating: Binary_Classification_Apnea/non_apnea/32279.png
#   inflating: Binary_Classification_Apnea/non_apnea/32280.png
#   inflating: Binary_Classification_Apnea/non_apnea/32281.png
#   inflating: Binary_Classification_Apnea/non_apnea/32282.png
#   inflating: Binary_Classification_Apnea/non_apnea/32283.png
#   inflating: Binary_Classification_Apnea/non_apnea/32284.png
#   inflating: Binary_Classification_Apnea/non_apnea/32285.png
#   inflating: Binary_Classification_Apnea/non_apnea/32286.png
#   inflating: Binary_Classification_Apnea/non_apnea/32287.png
#   inflating: Binary_Classification_Apnea/non_apnea/32288.png
#   inflating: Binary_Classification_Apnea/non_apnea/32289.png
#   inflating: Binary_Classification_Apnea/non_apnea/32290.png
#   inflating: Binary_Classification_Apnea/non_apnea/32291.png
#   inflating: Binary_Classification_Apnea/non_apnea/32292.png
#   inflating: Binary_Classification_Apnea/non_apnea/32293.png
#   inflating: Binary_Classification_Apnea/non_apnea/32294.png
#   inflating: Binary_Classification_Apnea/non_apnea/32295.png
#   inflating: Binary_Classification_Apnea/non_apnea/32296.png
#   inflating: Binary_Classification_Apnea/non_apnea/32297.png
#   inflating: Binary_Classification_Apnea/non_apnea/32298.png
#   inflating: Binary_Classification_Apnea/non_apnea/32299.png
#   inflating: Binary_Classification_Apnea/non_apnea/32300.png
#   inflating: Binary_Classification_Apnea/non_apnea/32301.png
#   inflating: Binary_Classification_Apnea/non_apnea/32302.png
#   inflating: Binary_Classification_Apnea/non_apnea/32303.png
#   inflating: Binary_Classification_Apnea/non_apnea/32304.png
#   inflating: Binary_Classification_Apnea/non_apnea/32305.png
#   inflating: Binary_Classification_Apnea/non_apnea/32306.png
#   inflating: Binary_Classification_Apnea/non_apnea/32307.png
#   inflating: Binary_Classification_Apnea/non_apnea/32308.png
#   inflating: Binary_Classification_Apnea/non_apnea/32309.png
#   inflating: Binary_Classification_Apnea/non_apnea/3231.png
#   inflating: Binary_Classification_Apnea/non_apnea/32310.png
#   inflating: Binary_Classification_Apnea/non_apnea/32311.png
#   inflating: Binary_Classification_Apnea/non_apnea/32312.png
#   inflating: Binary_Classification_Apnea/non_apnea/32313.png
#   inflating: Binary_Classification_Apnea/non_apnea/32314.png
#   inflating: Binary_Classification_Apnea/non_apnea/32315.png
#   inflating: Binary_Classification_Apnea/non_apnea/32316.png
#   inflating: Binary_Classification_Apnea/non_apnea/32317.png
#   inflating: Binary_Classification_Apnea/non_apnea/32318.png
#   inflating: Binary_Classification_Apnea/non_apnea/32319.png
#   inflating: Binary_Classification_Apnea/non_apnea/3232.png
#   inflating: Binary_Classification_Apnea/non_apnea/32320.png
#   inflating: Binary_Classification_Apnea/non_apnea/32321.png
#   inflating: Binary_Classification_Apnea/non_apnea/32322.png
#   inflating: Binary_Classification_Apnea/non_apnea/32323.png
#   inflating: Binary_Classification_Apnea/non_apnea/32324.png
#   inflating: Binary_Classification_Apnea/non_apnea/32325.png
#   inflating: Binary_Classification_Apnea/non_apnea/32326.png
#   inflating: Binary_Classification_Apnea/non_apnea/32327.png
#   inflating: Binary_Classification_Apnea/non_apnea/32328.png
#   inflating: Binary_Classification_Apnea/non_apnea/32329.png
#   inflating: Binary_Classification_Apnea/non_apnea/3233.png
#   inflating: Binary_Classification_Apnea/non_apnea/32330.png
#   inflating: Binary_Classification_Apnea/non_apnea/32331.png
#   inflating: Binary_Classification_Apnea/non_apnea/32332.png
#   inflating: Binary_Classification_Apnea/non_apnea/32333.png
#   inflating: Binary_Classification_Apnea/non_apnea/32334.png
# ...
#   inflating: Binary_Classification_Apnea/non_apnea/9429.png
#   inflating: Binary_Classification_Apnea/non_apnea/9430.png
#   inflating: Binary_Classification_Apnea/non_apnea/9431.png
#   inflating: Binary_Classification_Apnea/non_apnea/9432.png
#   inflating: Binary_Classification_Apnea/non_apnea/9433.png
#   inflating: Binary_Classification_Apnea/non_apnea/9434.png
#   inflating: Binary_Classification_Apnea/non_apnea/9435.png
#   inflating: Binary_Classification_Apnea/non_apnea/9436.png
#   inflating: Binary_Classification_Apnea/non_apnea/9437.png
#   inflating: Binary_Classification_Apnea/non_apnea/9438.png
#   inflating: Binary_Classification_Apnea/non_apnea/9439.png
#   inflating: Binary_Classification_Apnea/non_apnea/9440.png
#   inflating: Binary_Classification_Apnea/non_apnea/9441.png
#   inflating: Binary_Classification_Apnea/non_apnea/9442.png
#   inflating: Binary_Classification_Apnea/non_apnea/9443.png
#   inflating: Binary_Classification_Apnea/non_apnea/9444.png
#   inflating: Binary_Classification_Apnea/non_apnea/9445.png
#   inflating: Binary_Classification_Apnea/non_apnea/9446.png
#   inflating: Binary_Classification_Apnea/non_apnea/9447.png
#   inflating: Binary_Classification_Apnea/non_apnea/9448.png
#   inflating: Binary_Classification_Apnea/non_apnea/9449.png
#   inflating: Binary_Classification_Apnea/non_apnea/9450.png
#   inflating: Binary_Classification_Apnea/non_apnea/9451.png
#   inflating: Binary_Classification_Apnea/non_apnea/9452.png
#   inflating: Binary_Classification_Apnea/non_apnea/9453.png
#   inflating: Binary_Classification_Apnea/non_apnea/9454.png
#   inflating: Binary_Classification_Apnea/non_apnea/9455.png
#   inflating: Binary_Classification_Apnea/non_apnea/9456.png
#   inflating: Binary_Classification_Apnea/non_apnea/9457.png
#   inflating: Binary_Classification_Apnea/non_apnea/9458.png
#   inflating: Binary_Classification_Apnea/non_apnea/9459.png
#   inflating: Binary_Classification_Apnea/non_apnea/9460.png
#   inflating: Binary_Classification_Apnea/non_apnea/9461.png
#   inflating: Binary_Classification_Apnea/non_apnea/9484.png
#   inflating: Binary_Classification_Apnea/non_apnea/9485.png
#   inflating: Binary_Classification_Apnea/non_apnea/9495.png
#   inflating: Binary_Classification_Apnea/non_apnea/9496.png
#   inflating: Binary_Classification_Apnea/non_apnea/9497.png
#   inflating: Binary_Classification_Apnea/non_apnea/9498.png
#   inflating: Binary_Classification_Apnea/non_apnea/9499.png
#   inflating: Binary_Classification_Apnea/non_apnea/9500.png
#   inflating: Binary_Classification_Apnea/non_apnea/9504.png
#   inflating: Binary_Classification_Apnea/non_apnea/9505.png
#   inflating: Binary_Classification_Apnea/non_apnea/9536.png
#   inflating: Binary_Classification_Apnea/non_apnea/9537.png
#   inflating: Binary_Classification_Apnea/non_apnea/9538.png
#   inflating: Binary_Classification_Apnea/non_apnea/9539.png
#   inflating: Binary_Classification_Apnea/non_apnea/9547.png
#   inflating: Binary_Classification_Apnea/non_apnea/9548.png
#   inflating: Binary_Classification_Apnea/non_apnea/9549.png
#   inflating: Binary_Classification_Apnea/non_apnea/9601.png
#   inflating: Binary_Classification_Apnea/non_apnea/9602.png
#   inflating: Binary_Classification_Apnea/non_apnea/9607.png
#   inflating: Binary_Classification_Apnea/non_apnea/9608.png
#   inflating: Binary_Classification_Apnea/non_apnea/9609.png
#   inflating: Binary_Classification_Apnea/non_apnea/9612.png
#   inflating: Binary_Classification_Apnea/non_apnea/9613.png
#   inflating: Binary_Classification_Apnea/non_apnea/9614.png
#   inflating: Binary_Classification_Apnea/non_apnea/9615.png
#   inflating: Binary_Classification_Apnea/non_apnea/9616.png
#   inflating: Binary_Classification_Apnea/non_apnea/9617.png
#   inflating: Binary_Classification_Apnea/non_apnea/9678.png
#   inflating: Binary_Classification_Apnea/non_apnea/9679.png
#   inflating: Binary_Classification_Apnea/non_apnea/9680.png
#   inflating: Binary_Classification_Apnea/non_apnea/9693.png
#   inflating: Binary_Classification_Apnea/non_apnea/9694.png
#   inflating: Binary_Classification_Apnea/non_apnea/9695.png
#   inflating: Binary_Classification_Apnea/non_apnea/9696.png
#   inflating: Binary_Classification_Apnea/non_apnea/9697.png
#   inflating: Binary_Classification_Apnea/non_apnea/9698.png
#   inflating: Binary_Classification_Apnea/non_apnea/9699.png
#   inflating: Binary_Classification_Apnea/non_apnea/9700.png
#   inflating: Binary_Classification_Apnea/non_apnea/9701.png
#   inflating: Binary_Classification_Apnea/non_apnea/9702.png
#   inflating: Binary_Classification_Apnea/non_apnea/9703.png
#   inflating: Binary_Classification_Apnea/non_apnea/9704.png
#   inflating: Binary_Classification_Apnea/non_apnea/9705.png
#   inflating: Binary_Classification_Apnea/non_apnea/9713.png
#   inflating: Binary_Classification_Apnea/non_apnea/9714.png
#   inflating: Binary_Classification_Apnea/non_apnea/9715.png
#   inflating: Binary_Classification_Apnea/non_apnea/9716.png
#   inflating: Binary_Classification_Apnea/non_apnea/9717.png
#   inflating: Binary_Classification_Apnea/non_apnea/9718.png
#   inflating: Binary_Classification_Apnea/non_apnea/9719.png
#   inflating: Binary_Classification_Apnea/non_apnea/9720.png
#   inflating: Binary_Classification_Apnea/non_apnea/9721.png
#   inflating: Binary_Classification_Apnea/non_apnea/9722.png
#   inflating: Binary_Classification_Apnea/non_apnea/9723.png
#   inflating: Binary_Classification_Apnea/non_apnea/9724.png
#   inflating: Binary_Classification_Apnea/non_apnea/9725.png
#   inflating: Binary_Classification_Apnea/non_apnea/9726.png
#   inflating: Binary_Classification_Apnea/non_apnea/9727.png
#   inflating: Binary_Classification_Apnea/non_apnea/9728.png
#   inflating: Binary_Classification_Apnea/non_apnea/9729.png
#   inflating: Binary_Classification_Apnea/non_apnea/9730.png
#   inflating: Binary_Classification_Apnea/non_apnea/9731.png
#   inflating: Binary_Classification_Apnea/non_apnea/9732.png
#   inflating: Binary_Classification_Apnea/non_apnea/9733.png
#   inflating: Binary_Classification_Apnea/non_apnea/9734.png
#   inflating: Binary_Classification_Apnea/non_apnea/9735.png
#   inflating: Binary_Classification_Apnea/non_apnea/9736.png
#   inflating: Binary_Classification_Apnea/non_apnea/9737.png
#   inflating: Binary_Classification_Apnea/non_apnea/9738.png
#   inflating: Binary_Classification_Apnea/non_apnea/9739.png
#   inflating: Binary_Classification_Apnea/non_apnea/9740.png
#   inflating: Binary_Classification_Apnea/non_apnea/9741.png
#   inflating: Binary_Classification_Apnea/non_apnea/9742.png
#   inflating: Binary_Classification_Apnea/non_apnea/9743.png
#   inflating: Binary_Classification_Apnea/non_apnea/9744.png
#   inflating: Binary_Classification_Apnea/non_apnea/9751.png
#   inflating: Binary_Classification_Apnea/non_apnea/9752.png
#   inflating: Binary_Classification_Apnea/non_apnea/9753.png
#   inflating: Binary_Classification_Apnea/non_apnea/9754.png
#   inflating: Binary_Classification_Apnea/non_apnea/9755.png
#   inflating: Binary_Classification_Apnea/non_apnea/9756.png
#   inflating: Binary_Classification_Apnea/non_apnea/9757.png
#   inflating: Binary_Classification_Apnea/non_apnea/9758.png
#   inflating: Binary_Classification_Apnea/non_apnea/9759.png
#   inflating: Binary_Classification_Apnea/non_apnea/9760.png
#   inflating: Binary_Classification_Apnea/non_apnea/9761.png
#   inflating: Binary_Classification_Apnea/non_apnea/9762.png
#   inflating: Binary_Classification_Apnea/non_apnea/9763.png
#   inflating: Binary_Classification_Apnea/non_apnea/9764.png
#   inflating: Binary_Classification_Apnea/non_apnea/979.png
#   inflating: Binary_Classification_Apnea/non_apnea/980.png
#   inflating: Binary_Classification_Apnea/non_apnea/9804.png
#   inflating: Binary_Classification_Apnea/non_apnea/9805.png
#   inflating: Binary_Classification_Apnea/non_apnea/9806.png
#   inflating: Binary_Classification_Apnea/non_apnea/9807.png
#   inflating: Binary_Classification_Apnea/non_apnea/9808.png
#   inflating: Binary_Classification_Apnea/non_apnea/9809.png
#   inflating: Binary_Classification_Apnea/non_apnea/981.png
#   inflating: Binary_Classification_Apnea/non_apnea/9810.png
#   inflating: Binary_Classification_Apnea/non_apnea/9811.png
#   inflating: Binary_Classification_Apnea/non_apnea/9812.png
#   inflating: Binary_Classification_Apnea/non_apnea/9813.png
#   inflating: Binary_Classification_Apnea/non_apnea/9814.png
#   inflating: Binary_Classification_Apnea/non_apnea/9815.png
#   inflating: Binary_Classification_Apnea/non_apnea/9816.png
#   inflating: Binary_Classification_Apnea/non_apnea/9817.png
#   inflating: Binary_Classification_Apnea/non_apnea/982.png
#   inflating: Binary_Classification_Apnea/non_apnea/9821.png
#   inflating: Binary_Classification_Apnea/non_apnea/9822.png
#   inflating: Binary_Classification_Apnea/non_apnea/9823.png
#   inflating: Binary_Classification_Apnea/non_apnea/9824.png
#   inflating: Binary_Classification_Apnea/non_apnea/9825.png
#   inflating: Binary_Classification_Apnea/non_apnea/9826.png
#   inflating: Binary_Classification_Apnea/non_apnea/9827.png
#   inflating: Binary_Classification_Apnea/non_apnea/9828.png
#   inflating: Binary_Classification_Apnea/non_apnea/9829.png
#   inflating: Binary_Classification_Apnea/non_apnea/983.png
#   inflating: Binary_Classification_Apnea/non_apnea/9830.png
#   inflating: Binary_Classification_Apnea/non_apnea/9831.png
#   inflating: Binary_Classification_Apnea/non_apnea/9832.png
#   inflating: Binary_Classification_Apnea/non_apnea/9833.png
#   inflating: Binary_Classification_Apnea/non_apnea/9834.png
#   inflating: Binary_Classification_Apnea/non_apnea/9835.png
#   inflating: Binary_Classification_Apnea/non_apnea/9836.png
#   inflating: Binary_Classification_Apnea/non_apnea/9837.png
#   inflating: Binary_Classification_Apnea/non_apnea/9838.png
#   inflating: Binary_Classification_Apnea/non_apnea/9839.png
#   inflating: Binary_Classification_Apnea/non_apnea/984.png
#   inflating: Binary_Classification_Apnea/non_apnea/9840.png
#   inflating: Binary_Classification_Apnea/non_apnea/9841.png
#   inflating: Binary_Classification_Apnea/non_apnea/9842.png
#   inflating: Binary_Classification_Apnea/non_apnea/9843.png
#   inflating: Binary_Classification_Apnea/non_apnea/9844.png
#   inflating: Binary_Classification_Apnea/non_apnea/9845.png
#   inflating: Binary_Classification_Apnea/non_apnea/9846.png
#   inflating: Binary_Classification_Apnea/non_apnea/9847.png
#   inflating: Binary_Classification_Apnea/non_apnea/9848.png
#   inflating: Binary_Classification_Apnea/non_apnea/9849.png
#   inflating: Binary_Classification_Apnea/non_apnea/985.png
#   inflating: Binary_Classification_Apnea/non_apnea/9850.png
#   inflating: Binary_Classification_Apnea/non_apnea/9851.png
#   inflating: Binary_Classification_Apnea/non_apnea/986.png
#   inflating: Binary_Classification_Apnea/non_apnea/987.png
#   inflating: Binary_Classification_Apnea/non_apnea/9905.png
#   inflating: Binary_Classification_Apnea/non_apnea/9906.png
#   inflating: Binary_Classification_Apnea/non_apnea/9907.png
#   inflating: Binary_Classification_Apnea/non_apnea/9908.png
#   inflating: Binary_Classification_Apnea/non_apnea/9916.png
#   inflating: Binary_Classification_Apnea/non_apnea/9917.png
#   inflating: Binary_Classification_Apnea/non_apnea/9918.png
#   inflating: Binary_Classification_Apnea/non_apnea/9919.png
#   inflating: Binary_Classification_Apnea/non_apnea/9920.png
#   inflating: Binary_Classification_Apnea/non_apnea/9921.png
#   inflating: Binary_Classification_Apnea/non_apnea/9922.png
#   inflating: Binary_Classification_Apnea/non_apnea/9923.png
#   inflating: Binary_Classification_Apnea/non_apnea/9924.png
#   inflating: Binary_Classification_Apnea/non_apnea/9925.png
#   inflating: Binary_Classification_Apnea/non_apnea/9926.png
#   inflating: Binary_Classification_Apnea/non_apnea/9927.png
#   inflating: Binary_Classification_Apnea/non_apnea/9928.png
#   inflating: Binary_Classification_Apnea/non_apnea/9929.png
#   inflating: Binary_Classification_Apnea/non_apnea/9930.png
#   inflating: Binary_Classification_Apnea/non_apnea/9931.png
#   inflating: Binary_Classification_Apnea/non_apnea/9932.png
#   inflating: Binary_Classification_Apnea/non_apnea/9933.png
#   inflating: Binary_Classification_Apnea/non_apnea/9934.png
#   inflating: Binary_Classification_Apnea/non_apnea/9935.png
#   inflating: Binary_Classification_Apnea/non_apnea/9936.png
#   inflating: Binary_Classification_Apnea/non_apnea/9937.png
#   inflating: Binary_Classification_Apnea/non_apnea/9938.png
#   inflating: Binary_Classification_Apnea/non_apnea/9939.png
#   inflating: Binary_Classification_Apnea/non_apnea/9940.png
#   inflating: Binary_Classification_Apnea/non_apnea/9941.png
#   inflating: Binary_Classification_Apnea/non_apnea/9942.png
#   inflating: Binary_Classification_Apnea/non_apnea/9943.png
#   inflating: Binary_Classification_Apnea/non_apnea/9944.png
#   inflating: Binary_Classification_Apnea/non_apnea/9945.png
#   inflating: Binary_Classification_Apnea/non_apnea/9946.png
#   inflating: Binary_Classification_Apnea/non_apnea/9947.png
#   inflating: Binary_Classification_Apnea/non_apnea/9948.png
#   inflating: Binary_Classification_Apnea/non_apnea/9949.png
#   inflating: Binary_Classification_Apnea/non_apnea/9950.png
#   inflating: Binary_Classification_Apnea/non_apnea/9951.png
#   inflating: Binary_Classification_Apnea/non_apnea/9952.png
#   inflating: Binary_Classification_Apnea/non_apnea/9953.png
#   inflating: Binary_Classification_Apnea/non_apnea/9954.png
#   inflating: Binary_Classification_Apnea/non_apnea/9955.png
#   inflating: Binary_Classification_Apnea/non_apnea/9956.png
#   inflating: Binary_Classification_Apnea/non_apnea/9957.png
#   inflating: Binary_Classification_Apnea/non_apnea/9958.png
#   inflating: Binary_Classification_Apnea/non_apnea/9959.png
#   inflating: Binary_Classification_Apnea/non_apnea/9960.png
#   inflating: Binary_Classification_Apnea/non_apnea/9961.png
#   inflating: Binary_Classification_Apnea/non_apnea/9962.png
#   inflating: Binary_Classification_Apnea/non_apnea/9963.png
#   inflating: Binary_Classification_Apnea/non_apnea/9964.png
#   inflating: Binary_Classification_Apnea/non_apnea/9965.png
#   inflating: Binary_Classification_Apnea/non_apnea/9966.png
#   inflating: Binary_Classification_Apnea/non_apnea/9967.png
#   inflating: Binary_Classification_Apnea/non_apnea/9968.png
#   inflating: Binary_Classification_Apnea/non_apnea/9969.png
#   inflating: Binary_Classification_Apnea/non_apnea/9970.png
#   inflating: Binary_Classification_Apnea/non_apnea/9971.png
#   inflating: Binary_Classification_Apnea/non_apnea/9972.png
#   inflating: Binary_Classification_Apnea/non_apnea/9973.png
#   inflating: Binary_Classification_Apnea/non_apnea/9974.png
#   inflating: Binary_Classification_Apnea/non_apnea/9975.png
#   inflating: Binary_Classification_Apnea/non_apnea/9976.png
#   inflating: Binary_Classification_Apnea/non_apnea/9977.png
#   inflating: Binary_Classification_Apnea/non_apnea/9978.png
#   inflating: Binary_Classification_Apnea/non_apnea/9979.png
#   inflating: Binary_Classification_Apnea/non_apnea/9980.png
#   inflating: Binary_Classification_Apnea/non_apnea/9981.png
#   inflating: Binary_Classification_Apnea/non_apnea/9982.png
#   inflating: Binary_Classification_Apnea/non_apnea/9983.png
#   inflating: Binary_Classification_Apnea/non_apnea/9984.png
#   inflating: Binary_Classification_Apnea/non_apnea/9990.png
#   inflating: Binary_Classification_Apnea/non_apnea/9991.png
#   inflating: Binary_Classification_Apnea/non_apnea/9992.png
#   inflating: Binary_Classification_Apnea/non_apnea/9993.png
#   inflating: Binary_Classification_Apnea/non_apnea/9994.png
#   inflating: Binary_Classification_Apnea/non_apnea/9995.png
#   inflating: Binary_Classification_Apnea/non_apnea/9996.png
#   inflating: Binary_Classification_Apnea/non_apnea/9997.png

# %%
import os
import numpy as np
import matplotlib.pyplot as plt
from skimage import io, transform
from skimage.feature import graycomatrix, graycoprops
from sklearn.decomposition import PCA
from sklearn.manifold import TSNE
import random

def load_images(folder, target_size=(128, 180), num_images=None):
    all_image_files = [f for f in os.listdir(folder) if f.endswith((".png", ".jpg", ".jpeg"))]

    if num_images is not None:
        num_images = min(num_images, len(all_image_files))
        selected_files = random.sample(all_image_files, num_images)
    else:
        selected_files = all_image_files

    images = []
    for filename in selected_files:
        img_path = os.path.join(folder, filename)
        try:
            img = io.imread(img_path, as_gray=True)
            img = transform.resize(img, target_size, anti_aliasing=True)
            images.append(img)
        except Exception as e:
            print(f"Error loading image {filename}: {str(e)}")

    return np.array(images)


def plot_sample_images(apnea_images, non_apnea_images, num_samples=5):
    fig, axes = plt.subplots(2, num_samples, figsize=(20, 8))
    for i in range(num_samples):
        if i < len(apnea_images):
            axes[0, i].imshow(apnea_images[i], cmap="gray")
            axes[0, i].set_title(f"Apnea {i+1}")
            axes[0, i].axis("off")

        if i < len(non_apnea_images):
            axes[1, i].imshow(non_apnea_images[i], cmap="gray")
            axes[1, i].set_title(f"Non-Apnea {i+1}")
            axes[1, i].axis("off")
    plt.tight_layout()
    plt.show()


def plot_average_images(apnea_images, non_apnea_images):
    avg_apnea = np.mean(apnea_images, axis=0)
    avg_non_apnea = np.mean(non_apnea_images, axis=0)

    fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(12, 6))
    ax1.imshow(avg_apnea, cmap="gray")
    ax1.set_title("Average Apnea Spectrogram")
    ax1.axis("off")

    ax2.imshow(avg_non_apnea, cmap="gray")
    ax2.set_title("Average Non-Apnea Spectrogram")
    ax2.axis("off")

    plt.tight_layout()
    plt.show()


def plot_pixel_intensity_histograms(apnea_images, non_apnea_images):
    apnea_hist = np.histogram(apnea_images.flatten(), bins=256, range=(0, 1))[0]
    non_apnea_hist = np.histogram(non_apnea_images.flatten(), bins=256, range=(0, 1))[0]

    plt.figure(figsize=(10, 6))
    plt.plot(apnea_hist, label="Apnea", alpha=0.7)
    plt.plot(non_apnea_hist, label="Non-Apnea", alpha=0.7)
    plt.title("Pixel Intensity Histograms")
    plt.xlabel("Pixel Intensity")
    plt.ylabel("Frequency")
    plt.legend()
    plt.show()



def extract_glcm_features(image):
    # Convert float image (0-1) to uint8 (0-255)
    image_uint8 = (image * 255).astype(np.uint8)

    distances = [1]
    angles = [0, np.pi/4, np.pi/2, 3*np.pi/4]

    glcm = graycomatrix(image_uint8, distances, angles, 256, symmetric=True, normed=True)

    contrast = graycoprops(glcm, 'contrast')[0, 0]
    dissimilarity = graycoprops(glcm, 'dissimilarity')[0, 0]
    homogeneity = graycoprops(glcm, 'homogeneity')[0, 0]
    energy = graycoprops(glcm, 'energy')[0, 0]
    correlation = graycoprops(glcm, 'correlation')[0, 0]

    return [contrast, dissimilarity, homogeneity, energy, correlation]


def plot_glcm_features(apnea_images, non_apnea_images):
    # Diagnostic information
    print(f"Shape of apnea_images: {apnea_images.shape}")
    print(f"Shape of non_apnea_images: {non_apnea_images.shape}")
    print(f"Data type of apnea_images: {apnea_images.dtype}")
    print(f"Data type of non_apnea_images: {non_apnea_images.dtype}")
    print(f"Min value in apnea_images: {np.min(apnea_images)}")
    print(f"Max value in apnea_images: {np.max(apnea_images)}")
    print(f"Min value in non_apnea_images: {np.min(non_apnea_images)}")
    print(f"Max value in non_apnea_images: {np.max(non_apnea_images)}")

    # Check if images are already in integer format
    if np.issubdtype(apnea_images.dtype, np.integer) and np.issubdtype(non_apnea_images.dtype, np.integer):
        print("Images are already in integer format")
    else:
        print("Images are in float format")

    # Rest of the function remains the same
    apnea_features = np.array([extract_glcm_features(img) for img in apnea_images])
    non_apnea_features = np.array(
        [extract_glcm_features(img) for img in non_apnea_images]
    )

    feature_names = [
        "Contrast",
        "Dissimilarity",
        "Homogeneity",
        "Energy",
        "Correlation",
    ]

    fig, axes = plt.subplots(2, 3, figsize=(15, 10))
    axes = axes.flatten()

    for i, feature in enumerate(feature_names):
        axes[i].boxplot(
            [apnea_features[:, i], non_apnea_features[:, i]],
            labels=["Apnea", "Non-Apnea"],
        )
        axes[i].set_title(feature)

    plt.tight_layout()
    plt.show()

def dimensionality_reduction(apnea_images, non_apnea_images):
    X = np.vstack(
        (
            apnea_images.reshape(len(apnea_images), -1),
            non_apnea_images.reshape(len(non_apnea_images), -1),
        )
    )
    y = np.hstack((np.ones(len(apnea_images)), np.zeros(len(non_apnea_images))))

    pca = PCA(n_components=3)
    X_pca = pca.fit_transform(X)

    tsne = TSNE(n_components=3, random_state=42)
    X_tsne = tsne.fit_transform(X)

    fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(15, 6))

    ax1.scatter(X_pca[y == 1, 0], X_pca[y == 1, 1], c="r", label="Apnea", alpha=0.7)
    ax1.scatter(X_pca[y == 0, 0], X_pca[y == 0, 1], c="b", label="Non-Apnea", alpha=0.7)
    ax1.set_title("PCA")
    ax1.legend()

    ax2.scatter(X_tsne[y == 1, 0], X_tsne[y == 1, 1], c="r", label="Apnea", alpha=0.7)
    ax2.scatter(
        X_tsne[y == 0, 0], X_tsne[y == 0, 1], c="b", label="Non-Apnea", alpha=0.7
    )
    ax2.set_title("t-SNE")
    ax2.legend()

    plt.tight_layout()
    plt.show()

# %%
# Main execution
apnea_folder = "./Binary_Classification_Apnea/apnea/"
non_apnea_folder = "./Binary_Classification_Apnea/non_apnea/"

apnea_images = load_images(apnea_folder,num_images=5000)
non_apnea_images = load_images(non_apnea_folder,num_images=5000)

print(f"Number of Apnea images: {len(apnea_images)}")
print(f"Number of Non-Apnea images: {len(non_apnea_images)}")
# Out:
# Number of Apnea images: 5000
# Number of Non-Apnea images: 5000

# %%
plot_sample_images(apnea_images, non_apnea_images)

# %%
plot_average_images(apnea_images, non_apnea_images)

# %%
plot_pixel_intensity_histograms(apnea_images, non_apnea_images)

# %%
plot_glcm_features(apnea_images, non_apnea_images)
# Out:
# Shape of apnea_images: (5000, 128, 180)
# Shape of non_apnea_images: (5000, 128, 180)
# Data type of apnea_images: float64
# Data type of non_apnea_images: float64
# Min value in apnea_images: 0.0
# Max value in apnea_images: 1.0
# Min value in non_apnea_images: 0.0
# Max value in non_apnea_images: 1.0
# Images are in float format

# %%
dimensionality_reduction(apnea_images, non_apnea_images)

# %%
import numpy as np
import pandas as pd
from skimage import measure
from scipy import stats
from tqdm import tqdm

def measure_image_metrics(image, label, index):
    return {
        'Label': label,
        'Image_Index': index,
        'Mean_Intensity': np.mean(image),
        'Std_Intensity': np.std(image),
        'Min_Intensity': np.min(image),
        'Max_Intensity': np.max(image),
        'Entropy': measure.shannon_entropy(image),
        'SNR': np.mean(image) / np.std(image) if np.std(image) != 0 else 0,
        'Contrast': np.max(image) - np.min(image),
        'Skewness': stats.skew(image.flatten()),
        'Kurtosis': stats.kurtosis(image.flatten()),
        '10th_Percentile': np.percentile(image, 10),
        '90th_Percentile': np.percentile(image, 90),
    }

def create_metrics_dataframe(apnea_images, non_apnea_images, batch_size=100):
    total_images = len(apnea_images) + len(non_apnea_images)
    metrics = []

    with tqdm(total=total_images, desc="Processing Images") as pbar:
        for i in range(0, len(apnea_images), batch_size):
            batch = apnea_images[i:i+batch_size]
            metrics.extend([measure_image_metrics(img, 'Apnea', idx) for idx, img in enumerate(batch, start=i)])
            pbar.update(len(batch))

        for i in range(0, len(non_apnea_images), batch_size):
            batch = non_apnea_images[i:i+batch_size]
            metrics.extend([measure_image_metrics(img, 'Non-Apnea', idx) for idx, img in enumerate(batch, start=i)])
            pbar.update(len(batch))

    df = pd.DataFrame(metrics)
    return df

# Assuming apnea_images and non_apnea_images are already loaded
print("Starting metrics calculation...")
df_metrics = create_metrics_dataframe(apnea_images, non_apnea_images)

print("\nSummary statistics:")
print(df_metrics.groupby('Label').mean())

print("\nSaving metrics to CSV...")
df_metrics.to_csv('image_metrics.csv', index=False)
print("Full metrics saved to 'image_metrics.csv'")

# Additional analysis
print("\nPerforming additional analysis...")
for column in df_metrics.columns:
    if column not in ['Label', 'Image_Index']:
        t_stat, p_value = stats.ttest_ind(
            df_metrics[df_metrics['Label'] == 'Apnea'][column],
            df_metrics[df_metrics['Label'] == 'Non-Apnea'][column]
        )
        print(f"{column}: t-statistic = {t_stat:.4f}, p-value = {p_value:.4f}")
# Out:
# Starting metrics calculation...
# Processing Images: 100%|██████████| 10000/10000 [00:50<00:00, 197.50it/s]
# Summary statistics:
#            Image_Index  Mean_Intensity  Std_Intensity  Min_Intensity  \
# Label
# Apnea           2499.5        0.498655       0.113797       0.218907
# Non-Apnea       2499.5        0.500208       0.113792       0.261068
#
#            Max_Intensity   Entropy       SNR  Contrast  Skewness  Kurtosis  \
# Label
# Apnea           0.792530  6.049353  6.909719  0.573623  0.087206  0.388571
# Non-Apnea       0.743728  5.839320  8.959699  0.482660  0.007047 -0.297564
#
#            10th_Percentile  90th_Percentile
# Label
# Apnea             0.351951         0.644143
# Non-Apnea         0.350269         0.649544
#
# Saving metrics to CSV...
# Full metrics saved to 'image_metrics.csv'
#
# Performing additional analysis...
# Mean_Intensity: t-statistic = -0.9448, p-value = 0.3448
# Std_Intensity: t-statistic = 0.0034, p-value = 0.9973
# Min_Intensity: t-statistic = -14.4171, p-value = 0.0000
# Max_Intensity: t-statistic = 15.7717, p-value = 0.0000
# Entropy: t-statistic = 10.8241, p-value = 0.0000
# SNR: t-statistic = -12.7978, p-value = 0.0000
# Contrast: t-statistic = 16.1155, p-value = 0.0000
# Skewness: t-statistic = 7.5470, p-value = 0.0000
# Kurtosis: t-statistic = 23.8316, p-value = 0.0000
# 10th_Percentile: t-statistic = 0.6525, p-value = 0.5141
# 90th_Percentile: t-statistic = -1.9337, p-value = 0.0532

# %%
df_metrics
# Out:
#           Label  Image_Index  Mean_Intensity  Std_Intensity  Min_Intensity  \
# 0         Apnea            0        0.481661       0.080431       0.121569
# 1         Apnea            1        0.503738       0.034741       0.329412
# 2         Apnea            2        0.608601       0.205611       0.000000
# 3         Apnea            3        0.492964       0.044408       0.274510
# 4         Apnea            4        0.496181       0.032750       0.337255
# ...         ...          ...             ...            ...            ...
# 9995  Non-Apnea         4995        0.466114       0.036927       0.349020
# 9996  Non-Apnea         4996        0.441263       0.075858       0.294118
# 9997  Non-Apnea         4997        0.428640       0.118836       0.039216
# 9998  Non-Apnea         4998        0.466652       0.104989       0.215686
# 9999  Non-Apnea         4999        0.463363       0.057752       0.372549
#
#       Max_Intensity   Entropy        SNR  Contrast  Skewness  Kurtosis  \
# 0          0.850980  5.943013   5.988523  0.729412  0.396651  2.785864
# 1          0.650980  4.869069  14.499900  0.321569 -0.572615  2.676531
# 2          1.000000  7.364493   2.959966  1.000000 -0.446464 -0.271517
# 3          0.764706  5.028829  11.100852  0.490196  0.545192  5.083624
# 4          0.690196  4.447204  15.150404  0.352941 -0.178396  5.548577
# ...             ...       ...        ...       ...       ...       ...
# 9995       0.541176  4.876944  12.622687  0.192157 -0.154413 -0.866744
# 9996       0.694118  6.019398   5.816980  0.400000  0.397324 -0.149921
# 9997       0.596078  6.107302   3.606981  0.556863 -1.441367  1.222539
# 9998       0.752941  6.487069   4.444757  0.537255 -0.205783 -0.218888
# 9999       0.596078  5.503013   8.023263  0.223529  0.370444 -0.957266
#
#       10th_Percentile  90th_Percentile
# 0            0.411765         0.576471
# 1            0.462745         0.541176
# 2            0.305882         0.839216
# 3            0.443137         0.537255
# 4            0.466667         0.521569
# ...               ...              ...
# 9995         0.423529         0.513725
# 9996         0.345098         0.541176
# 9997         0.231373         0.529412
# 9998         0.313725         0.600000
# 9999         0.392157         0.552941
#
# [10000 rows x 13 columns]

# %%
import os
import cv2  # For image reading
import numpy as np
from skimage import filters, measure
from scipy.stats import skew, kurtosis
import shutil

# Function to compute Signal-to-Noise Ratio (SNR)
def compute_snr(image):
    signal = np.mean(image)
    noise = np.std(image)
    return signal / noise if noise != 0 else 0

# Function to compute entropy
def compute_entropy(image):
    histogram, _ = np.histogram(image, bins=256, range=(0, 1), density=True)
    histogram = histogram + 1e-10  # avoid log(0)
    return -np.sum(histogram * np.log2(histogram))

# Function to compute contrast
def compute_contrast(image):
    return np.std(image) / np.mean(image)

# Function to calculate key image metrics
def calculate_image_metrics(image):
    image = image.astype(float) / 255.0  # Normalize to [0,1] range
    snr = compute_snr(image)
    entropy = compute_entropy(image)
    contrast = compute_contrast(image)
    img_skew = skew(image.flatten())
    img_kurtosis = kurtosis(image.flatten())
    min_intensity = np.min(image)
    max_intensity = np.max(image)
    return snr, entropy, contrast, img_skew, img_kurtosis, min_intensity, max_intensity

# Filtering function based on dynamic threshold
def check_criteria(criteria, threshold):
    return sum(criteria) >= threshold

# Filtering function for Apnea images (threshold increased by 1)
def filter_apnea_image(image_metrics):
    snr, entropy, contrast, img_skew, img_kurtosis, min_intensity, max_intensity = image_metrics
    # Check conditions for Apnea images
    criteria = [
        snr < 7.5,
        entropy > 5.9,
        contrast > 0.55,
        img_skew > 0.05,
        img_kurtosis > 0.2,
        min_intensity < 0.23,
        max_intensity > 0.75
    ]
    # Apply filter with increased threshold (3 instead of 4)
    return check_criteria(criteria, threshold=3)

# Filtering function for Non-Apnea images (threshold increased by 2)
def filter_non_apnea_image(image_metrics):
    snr, entropy, contrast, img_skew, img_kurtosis, min_intensity, max_intensity = image_metrics
    # Check conditions for Non-Apnea images
    criteria = [
        snr > 8.5,
        entropy < 5.9,
        contrast < 0.5,
        img_skew < 0.05,
        img_kurtosis < 0,
        min_intensity > 0.26,
        max_intensity < 0.75
    ]
    # Apply filter with increased threshold (6 instead of 4)
    return check_criteria(criteria, threshold=6)

# Main function to process images and apply filtering
def filter_images(input_folder, output_folder, is_apnea):
    if not os.path.exists(output_folder):
        os.makedirs(output_folder)

    for img_file in os.listdir(input_folder):
        img_path = os.path.join(input_folder, img_file)
        img = cv2.imread(img_path, cv2.IMREAD_GRAYSCALE)  # Read in grayscale
        if img is None:
            continue

        # Calculate image metrics
        metrics = calculate_image_metrics(img)

        # Apply filters based on whether it's an Apnea or Non-Apnea folder
        if is_apnea and filter_apnea_image(metrics):
            shutil.copy(img_path, os.path.join(output_folder, img_file))
        elif not is_apnea and filter_non_apnea_image(metrics):
            shutil.copy(img_path, os.path.join(output_folder, img_file))


# Driver function to run the script
if __name__ == "__main__":
    # Set the input folders for Apnea and Non-Apnea images
    apnea_input_folder = './Binary_Classification_Apnea/apnea'
    non_apnea_input_folder = './Binary_Classification_Apnea/non_apnea'

    # Set the output folders for filtered Apnea and Non-Apnea images
    apnea_output_folder = './BCA/apnea'
    non_apnea_output_folder = './BCA/non_apnea'

    # Filter Apnea images
    print("Filtering Apnea images...")
    filter_images(apnea_input_folder, apnea_output_folder, is_apnea=True)

    # Filter Non-Apnea images
    print("Filtering Non-Apnea images...")
    filter_images(non_apnea_input_folder, non_apnea_output_folder, is_apnea=False)

    print("Filtering complete!")
# Out:
# Filtering Apnea images...
# Filtering Non-Apnea images...
# Filtering complete!
